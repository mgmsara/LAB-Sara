# %% [markdown]
# # She is incredible and she loves L.A.!
#
# ## Her name is Dalia and is my sister
# ### She is finishing her PhD in Los Angeles, I am missing her a lot, but I am very happy for her.  She thought she will not like L.A. but she like it! I will tell you a little it more about that.

# %% [markdown]
# *This notebook is a training about my sister Dalia in L.A., California.*

# %%
x = "Hollidays"

input(x)

# %%
# Add an image (first dowload the image in our cumputer and upload in the jupyter notebook). Call the IPython.display library Image.

# %%
from IPython.display import Image
Image("La. photo.jpeg")

# %%
# Add a video (first get the youtube link from Share > Embed). Call the IPython.display library HTML. Copy yor link.

# %%
from IPython.display import HTML

# %%
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/9wbNabuP6aM";controls=0&amp;showinfo=0" frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/9wbNabuP6aM";controls=0&amp;showinfo=0" frameborder="0" allowfullscreen></iframe>

# %%
# To create a list, change the cell to Markdown and create a list with: - list

# %% [markdown]
# She loves:
# - Go to the beach
# - Expend time with her colleagues at the campus
# - Enjoying the music scene in coffes and clubs

# %%
# She is incredible and she loves L.A.!
## Her name is Dalia and is my sister
### ...
#change cell to Markdown to change the size
