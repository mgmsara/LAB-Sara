# %% [markdown]
# # Using Pandas

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 200)
## to make it possible to display multiple output inside one cell 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# <b>load the data from the vehicles.csv file into pandas data frame

# %%
vehicles_df = pd.read_csv("data/vehicles.csv")
vehicles_df
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# First exploration of the dataset:
#
# - How many observations does it have?
# - Look at all the columns: do you understand what they mean?
# - Look at the raw data: do you see anything weird?
# - Look at the data types: are they the expected ones for the information the column contains?

# %%
## Your Code here df.Info()
#df.count())
#df.describe())
#df.mean())

vehicles_df.count()
# Out:
# Make                       35952
# Model                      35952
# Year                       35952
# Engine Displacement        35952
# Cylinders                  35952
# Transmission               35952
# Drivetrain                 35952
# Vehicle Class              35952
# Fuel Type                  35952
# Fuel Barrels/Year          35952
# City MPG                   35952
# Highway MPG                35952
# Combined MPG               35952
# CO2 Emission Grams/Mile    35952
# Fuel Cost/Year             35952
# dtype: int64

# %%
vehicles_df.describe()
# Out:
#               Year  Engine Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000         35952.000000  35952.000000       35952.000000
# mean    2000.71640             3.338493      5.765076          17.609056
# std       10.08529             1.359395      1.755268           4.467283
# min     1984.00000             0.600000      2.000000           0.060000
# 25%     1991.00000             2.200000      4.000000          14.699423
# 50%     2001.00000             3.000000      6.000000          17.347895
# 75%     2010.00000             4.300000      6.000000          20.600625
# max     2017.00000             8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# ...

# %%
type(vehicles_df)
# Out:
# pandas.core.frame.DataFrame

# %%
vehicles_df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
list(vehicles_df.columns)
# Out:
# ['Make',
#  'Model',
#  'Year',
#  'Engine Displacement',
#  'Cylinders',
#  'Transmission',
#  'Drivetrain',
#  'Vehicle Class',
#  'Fuel Type',
#  'Fuel Barrels/Year',
#  'City MPG',
#  'Highway MPG',
#  'Combined MPG',
#  'CO2 Emission Grams/Mile',
#  'Fuel Cost/Year']

# %%
#other version. We become an object - Index
column_names = (vehicles_df.columns)
print(column_names)
type(column_names)
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')
# pandas.core.indexes.base.Index

# %%
#other version. We become a list
column_names = (list(vehicles_df.columns))
print(column_names)
type(column_names)
# Out:
# ['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders', 'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type', 'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG', 'CO2 Emission Grams/Mile', 'Fuel Cost/Year']
# list

# %% [markdown]
# ### Cleaning and wrangling data
#
# - Some car brand names refer to the same brand. Replace all brand names that contain the word "Dutton" for simply "Dutton". If you find similar examples, clean their names too. Use `loc` with boolean indexing.
#
# - Convert CO2 Emissions from Grams/Mile to Grams/Km
#
# - Create a binary column that solely indicates if the transmission of a car is automatic or manual. Use `pandas.Series.str.startswith` and .
#
# - convert MPG columns to km_per_liter

# %% [markdown]
# Note:
# <br>Converting Grams/Mile to Grams/Km
#
# 1 Mile = 1.60934 Km
#
# Converting Gallons to Liters
#
# 1 Gallon = 3.78541 Liters

# %%
## Your Code here
#LOC
vehicles_df[vehicles_df["Make"].str.contains("Dutton")]
# Out:
#                                      Make               Model  Year  \
# 11012                  E. P. Dutton, Inc.       Funeral Coach  1985
# 30164  S and S Coach Company  E.p. Dutton  Funeral Coach  2WD  1984
# 31754    Superior Coaches Div E.p. Dutton  Funeral Coach  2WD  1984
#
#        Engine Displacement  Cylinders     Transmission         Drivetrain  \
# 11012                  4.1        8.0  Automatic 4-spd  Front-Wheel Drive
# 30164                  6.0        8.0  Automatic 3-spd      2-Wheel Drive
# 31754                  6.0        8.0  Automatic 3-spd      2-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 11012     Special Purpose Vehicles   Regular          19.388824        15
# 30164  Special Purpose Vehicle 2WD   Regular          32.961000         9
# 31754  Special Purpose Vehicle 2WD   Regular          32.961000        10
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# ...

# %%
#students_df.iloc[:4, 4] = [40, 50, 60, 70]

vehicles_df.loc[vehicles_df["Make"].str.contains("Dutton"), 'Make'] = 'Dutton'

# %%
vehicles_df[vehicles_df["Make"].str.contains("Dutton")]
# Out:
#          Make               Model  Year  Engine Displacement  Cylinders  \
# 11012  Dutton       Funeral Coach  1985                  4.1        8.0
# 30164  Dutton  Funeral Coach  2WD  1984                  6.0        8.0
# 31754  Dutton  Funeral Coach  2WD  1984                  6.0        8.0
#
#           Transmission         Drivetrain                Vehicle Class  \
# 11012  Automatic 4-spd  Front-Wheel Drive     Special Purpose Vehicles
# 30164  Automatic 3-spd      2-Wheel Drive  Special Purpose Vehicle 2WD
# 31754  Automatic 3-spd      2-Wheel Drive  Special Purpose Vehicle 2WD
#
#       Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 11012   Regular          19.388824        15           21            17
# 30164   Regular          32.961000         9           11            10
# 31754   Regular          32.961000        10           11            10
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year
# 11012               522.764706            1950
# ...

# %%
#Convert CO2 Emissions from Grams/Mile to Grams/Km
#1 Mile = 1.60934 Km
#students_df["py-score"]=students_df["py-score"]  * 1.5

vehicles_df["CO2 Emission Grams/Mile"] = vehicles_df['CO2 Emission Grams/Mile'] / 1.6 

vehicles_df["CO2 Emission Grams/Mile"]
# Out:
# 0        326.727941
# 1        427.259615
# 2        347.148438
# 3        427.259615
# 4        347.148438
#             ...
# 35947    152.500000
# 35948    151.875000
# 35949    152.500000
# 35950    153.750000
# 35951    159.375000
# Name: CO2 Emission Grams/Mile, Length: 35952, dtype: float64

# %%
vehicles_df.rename(columns={"CO2 Emission Grams/Mile": "CO2 Emission Grams/km"})
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
#Create a binary column that solely indicates if the transmission of a car is automatic or manual. 
#Use pandas.Series.str.startswith and convert MPG columns to km_per_liter 



def auto_manual_function(Transmission):
    if Transmission.startswith('A'):
        return "Auto"
    else:
        return "Manual"
    

#vehicles_df["AUTO_or_MANUAL"]= vehicles_df["AUTO_or_MANUAL"].apply(auto_manual_function)


vehicles_df.insert(loc = 15, column ='AUTO_or_MANUAL', value = vehicles_df["Transmission"].apply(auto_manual_function))

vehicles_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [180], in <cell line: 16>()
#      10         return "Manual"
#      13 #vehicles_df["AUTO_or_MANUAL"]= vehicles_df["AUTO_or_MANUAL"].apply(auto_manual_function)
# ---> 16 vehicles_df.insert(loc = 15, column ='AUTO_or_MANUAL', value = vehicles_df["Transmission"].apply(auto_manual_function))
#      18 vehicles_df
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4440, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4434     raise ValueError(
#    4435         "Cannot specify 'allow_duplicates=True' when "
#    4436         "'self.flags.allows_duplicate_labels' is False."
#    4437     )
#    4438 if not allow_duplicates and column in self.columns:
#    4439     # Should this be a different kind of error??
# -> 4440     raise ValueError(f"cannot insert {column}, already exists")
# ...

# %%
#Use pandas.Series.str.startswith and convert MPG columns to km_per_liter 
#Converting Gallons to Liters
#1 Gallon = 3.78541 Liters

def update_km_per_liter(x):
    return x / 1.6 * 3.7 
    

vehicles_df[["City MPG", 'Highway MPG', 'Combined MPG']]= vehicles_df[['City MPG', 'Highway MPG', 'Combined MPG']].apply(update_km_per_liter)

vehicles_df.rename(columns={"City MPG": "City KMPL"})


vehicles_df
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# ### Gathering insights:
#
# - How many car makers are there? How many models? Which car maker has the most cars in the dataset?
#
# - When were these cars made? How big is the engine of these cars?
#
# - What's the frequency of different transmissions, drivetrains and fuel types?
#
# - What's the car that consumes the least/most fuel?

# %%
#How many car makers are there?

        #vehicles_df.loc[:, 'Make'].sort_values()
        #vehicles_df.sort_values(groupby = ["Make"])
        #car_makers = list(vehicles_df.groupby("Make").groups)
        #print(vehicles_df.groupby(["Make"])['Make'].count())
        #car_makers
        #len(car_makers)
        #car_maker_dict = vehicles_df.groupby(["Make"])
        #count = 0
        #for key, value in car_maker_dict.items():
               # print(car_maker_dict.keys, count + len(value))

        #most_car_maker = car_maker_dict.values()  
        #type(most_car_maker)
        #most_car_maker
        #car_maker_dict

        #https://sparkbyexamples.com/pandas/pandas-add-column-to-dataframe/

print(vehicles_df.groupby(["Make"]).ngroups)

# How many models
print(vehicles_df.groupby('Model').ngroups)

# Which car maker has the most cars in the dataset?
vehicles_df.groupby(["Make"])['Make'].count().sort_values(ascending=False)
# Out:
# 125
# 3608
# Make
# Chevrolet                           3643
# Ford                                2946
# Dodge                               2360
# GMC                                 2347
# Toyota                              1836
# BMW                                 1677
# Mercedes-Benz                       1284
# Nissan                              1253
# Volkswagen                          1047
# Mitsubishi                           950
# Mazda                                915
# Audi                                 890
# Porsche                              862
# Honda                                836
# Jeep                                 829
# Pontiac                              784
# Subaru                               781
# Volvo                                717
# Hyundai                              662
# Chrysler                             641
# Buick                                537
# Mercury                              532
# ...

# %%
#When were these cars made? 

print(vehicles_df.groupby('Year') ['Year'].count().sort_values())
# Out:
# Year
# 1984     645
# 1997     755
# 1996     767
# 1998     791
# 2000     827
# 1999     828
# 2017     857
# 2001     902
# 1995     928
# 2002     961
# 1994     967
# 2003    1034
# 1990    1068
# 1993    1077
# 2006    1099
# 1992    1107
# 2010    1108
# 2004    1113
# 1988    1119
# 1991    1122
# 2011    1124
# 2007    1126
# 1989    1127
# 2012    1139
# 2005    1156
# 2013    1168
# 2009    1183
# 2008    1184
# 1986    1188
# 1987    1198
# 2014    1211
# 2016    1228
# 2015    1264
# 1985    1581
# Name: Year, dtype: int64

# %%
#How big is the engine of these cars?

print(vehicles_df.groupby('Engine Displacement') ['Engine Displacement'].max().sort_values(ascending=False))
# Out:
# Engine Displacement
# 8.4    8.4
# 8.3    8.3
# 8.0    8.0
# 7.4    7.4
# 7.0    7.0
# 6.8    6.8
# 6.7    6.7
# 6.6    6.6
# 6.5    6.5
# 6.4    6.4
# 6.3    6.3
# 6.2    6.2
# 6.1    6.1
# 6.0    6.0
# 5.9    5.9
# 5.8    5.8
# 5.7    5.7
# 5.6    5.6
# 5.5    5.5
# 5.4    5.4
# 5.3    5.3
# 5.2    5.2
# 5.0    5.0
# 4.9    4.9
# 4.8    4.8
# 4.7    4.7
# 4.6    4.6
# 4.5    4.5
# 4.4    4.4
# 4.3    4.3
# 4.2    4.2
# 4.1    4.1
# 4.0    4.0
# 3.9    3.9
# 3.8    3.8
# 3.7    3.7
# 3.6    3.6
# 3.5    3.5
# 3.4    3.4
# 3.3    3.3
# 3.2    3.2
# 3.1    3.1
# 3.0    3.0
# 2.9    2.9
# 2.8    2.8
# 2.7    2.7
# 2.6    2.6
# 2.5    2.5
# 2.4    2.4
# 2.3    2.3
# 2.2    2.2
# 2.1    2.1
# 2.0    2.0
# 1.9    1.9
# 1.8    1.8
# 1.7    1.7
# 1.6    1.6
# 1.5    1.5
# 1.4    1.4
# 1.3    1.3
# 1.2    1.2
# 1.1    1.1
# 1.0    1.0
# 0.9    0.9
# 0.6    0.6
# Name: Engine Displacement, dtype: float64

# %%
#What's the frequency of different transmissions, drivetrains and fuel types?
vehicles_df.groupby('Transmission').count()
len(vehicles_df.groupby('Transmission').count())

vehicles_df.groupby('Drivetrain').count()
len(vehicles_df.groupby('Drivetrain').count())
# Out:
#                                    Make  Model   Year  Engine Displacement  \
# Transmission
# Auto (AV)                             2      2      2                    2
# Auto (AV-S6)                          1      1      1                    1
# Auto (AV-S8)                          1      1      1                    1
# Auto(A1)                              1      1      1                    1
# Auto(AM-S6)                          92     92     92                   92
# Auto(AM-S7)                         256    256    256                  256
# Auto(AM-S8)                           6      6      6                    6
# Auto(AM-S9)                           1      1      1                    1
# Auto(AM5)                            12     12     12                   12
# Auto(AM6)                           110    110    110                  110
# Auto(AM7)                           157    157    157                  157
# ...

# %%
vehicles_df.groupby('Fuel Type').count()
len(vehicles_df.groupby('Fuel Type').count())
# Out:
#                               Make  Model   Year  Engine Displacement  \
# Fuel Type
# CNG                             60     60     60                   60
# Diesel                         911    911    911                  911
# Gasoline or E85               1195   1195   1195                 1195
# Gasoline or natural gas         20     20     20                   20
# Gasoline or propane              8      8      8                    8
# Midgrade                        74     74     74                   74
# Premium                       9921   9921   9921                 9921
# Premium Gas or Electricity      17     17     17                   17
# Premium and Electricity         20     20     20                   20
# Premium or E85                 121    121    121                  121
# Regular                      23587  23587  23587                23587
# Regular Gas and Electricity     16     16     16                   16
# ...

# %%
#What's the car that consumes the least/most fuel?
vehicles_df.groupby('Fuel Barrels/Year') ['Fuel Barrels/Year'].max().sort_values(ascending=False)
#47.087143 #0.060000

vehicles_df.groupby('Make') ['Fuel Barrels/Year'].max().sort_values(ascending=False)

most_fuel_consum = vehicles_df.groupby('Make') ['Fuel Barrels/Year'].max().sort_values(ascending=False)
#print(most_fuel_consum[key][0]
# Out:
# Fuel Barrels/Year
# 47.087143    47.087143
# 41.201250    41.201250
# 36.623333    36.623333
# 32.961000    32.961000
# 29.964545    29.964545
# 27.467500    27.467500
# 27.298929    27.298929
# 25.479000    25.479000
# 25.354615    25.354615
# 23.886563    23.886563
# 23.543571    23.543571
# 22.481471    22.481471
# 21.974000    21.974000
# 21.232500    21.232500
# 20.600625    20.600625
# 20.115000    20.115000
# 19.388824    19.388824
# 19.109250    19.109250
# 18.311667    18.311667
# 18.199286    18.199286
# 17.372045    17.372045
# 17.347895    17.347895
# 16.616739    16.616739
# 16.480500    16.480500
# 15.924375    15.924375
# 15.695714    15.695714
# 15.287400    15.287400
# 14.982273    14.982273
# 14.699423    14.699423
# 14.330870    14.330870
# 14.155000    14.155000
# 13.733750    13.733750
# 13.649464    13.649464
# 13.184400    13.184400
# 13.178793    13.178793
# 12.739500    12.739500
# 12.677308    12.677308
# 12.328548    12.328548
# 12.207778    12.207778
# ...

# %% [markdown]
# <b> (Optional)

# %%
vehicles_df.groupby('Make') ['Fuel Barrels/Year'].min().sort_values(ascending=True)
# Out:
# Make
# Honda                                0.060000
# Toyota                               0.080870
# Ford                                 0.103333
# Dodge                                0.109412
# VPG                                  0.143077
# Mobility Ventures LLC                0.143077
# GMC                                  0.155000
# Chevrolet                            0.155000
# BMW                                  1.563190
# Cadillac                             3.504650
# Hyundai                              3.835583
# Audi                                 5.115503
# Fisker                               6.359255
# Geo                                  7.012979
# Volkswagen                           7.324667
# Kia                                  7.847857
# Lexus                                7.847857
# Pontiac                              7.847857
# Suzuki                               7.847857
# Porsche                              7.984573
# ...

# %% [markdown]
# What brand has the worse CO2 Emissions on average?
#
# Hint: use the function `sort_values()`

# %%
## your Code here

sort_values()

# %% [markdown]
# Do cars with automatic transmission consume more fuel than cars with manual transmission on average?

# %%
## Your Code is here
